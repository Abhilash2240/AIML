# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhilash2240/AIML/blob/main/Assignment_2(AIML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

array1 = np.array([1, 2, 3, 4, 5])
array2 = np.array([6, 7, 8, 9, 10])

print(type(array1))
print(type(array2))

multiplication = array1 * array2
print("Multiplication:", multiplication)

division = array1 / array2
print("Division:", division)

power = array1 ** 2
print("Power:", power)

addition = array1 + array2
textual_output = f"Addition of Two: {addition}"
print(textual_output)

sine = np.sin(array1)
print("Sine:", sine)

logarithm = np.log(array1)
print("Logarithm:", logarithm)

logarithm_base2 = np.log2(array1)
print("Logarithm Base 2:", logarithm_base2)

exponential = np.exp(array1)
print("Exponential:", exponential)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Multiplication: [ 6 14 24 36 50]
# Division: [0.16666667 0.28571429 0.375      0.44444444 0.5       ]
# Power: [ 1  4  9 16 25]
# Addition of Two: [ 7  9 11 13 15]
# Sine: [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# Logarithm: [0.         0.69314718 1.09861229 1.38629436 1.60943791]
# Logarithm Base 2: [0.         1.         1.5849625  2.         2.32192809]
# Exponential: [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'person': ['kiran', 'arun', 'vijay', 'varun'],
    'age': [25, 30, 35, 40],
    'height': [145, 151, 165, 173],
    'weight': [45, 55, 65, 75]
}
df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.scatter(df['height'], df['weight'], color='r')
plt.title('Height vs Weight Scatter Plot')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(df['person'], df['age'], color='green')
plt.title('Age of Individuals')
plt.xlabel('Person')
plt.ylabel('Age (years)')
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(df['height'], bins=5, color='blue', edgecolor='black')
plt.title('Height Distribution')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.show()
